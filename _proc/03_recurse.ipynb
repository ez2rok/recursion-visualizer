# %% [raw]
# ---
# description: A class that provides a decorator for visualizing recursion trees and
#   caching results
# output-file: recurse.html
# title: recurse
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(RecursionVisualizer)
# Out:
# ---
#
# [source](https://github.com/ez2rok/recursion-visualizer/blob/master/recursion_visualizer/recurse.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### RecursionVisualizer
#
# >      RecursionVisualizer (verbose:bool=False, animate:bool=True,
# >                           save:bool=False, path:str='')
#
# A class that provides a decorator for visualizing recursion trees and caching results.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | verbose | bool | False | if true, print all nodes |
# | animate | bool | True | if true, create an animation of the recursion tree |
# | save | bool | False | if true, save the animation to a html file |
# | path | str |  | path to save the animation to |

# %%
#|output: asis
#| echo: false
show_doc(on_colab)
# Out:
# ---
#
# [source](https://github.com/ez2rok/recursion-visualizer/blob/master/recursion_visualizer/recurse.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### on_colab
#
# >      on_colab ()
#
# Returns true if code is being executed on Colab, false otherwise

# %%
on_colab()
# Out:
# False

# %%
@RecursionVisualizer()
def fib(n):
  if n <= 2: 
    return 1
  return fib(n-1) + fib(n-2)

# %%
#|output: true
fig, result = fib(5)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
result
# Out:
# 5
